# %%
import pandas as pd
import numpy as np
titanic_df = pd.read_csv(R'C:\Users\qwerty\Desktop\Новая папка (2)\МО\ЛР1\titanic3.csv', sep=';', thousands = ",")
print(titanic_df.head())
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket       fare    cabin embarked boat   body  \
# 0    29.0    0.0    0.0   24160  2113375.0       B5        S    2    NaN
# 1  9167.0    1.0    2.0  113781  1515500.0  C22 C26        S   11    NaN
# 2     2.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
# 3    30.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN  135.0
# 4    25.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
print(titanic_df.groupby(['sex', 'survived'])['ticket'].count())
# Out:
# sex     survived
# female  0.0         127
#         1.0         339
# male    0.0         682
#         1.0         161
# Name: ticket, dtype: int64

# %%
print(titanic_df.groupby( ['pclass', 'survived'] ) ['ticket'].count())
# Out:
# pclass  survived
# 1.0     0.0         123
#         1.0         200
# 2.0     0.0         158
#         1.0         119
# 3.0     0.0         528
#         1.0         181
# Name: ticket, dtype: int64

# %%
# %matplotlib inline
titanic_df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex     age  sibsp  parch  ticket       fare    cabin embarked boat  \
# ...

# %%
titanic_df.head(4)
# Out:
#    pclass  survived                                  name     sex     age  \
# 0     1.0       1.0         Allen, Miss. Elisabeth Walton  female    29.0
# 1     1.0       1.0        Allison, Master. Hudson Trevor    male  9167.0
# 2     1.0       0.0          Allison, Miss. Helen Loraine  female     2.0
# 3     1.0       0.0  Allison, Mr. Hudson Joshua Creighton    male    30.0
#
#    sibsp  parch  ticket       fare    cabin embarked boat   body  \
# 0    0.0    0.0   24160  2113375.0       B5        S    2    NaN
# 1    1.0    2.0  113781  1515500.0  C22 C26        S   11    NaN
# 2    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
# 3    1.0    2.0  113781  1515500.0  C22 C26        S  NaN  135.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
titanic_df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic_df[2:6]
# Out:
#    pclass  survived                                             name     sex  \
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5     1.0       1.0                              Anderson, Mr. Harry    male
#
#     age  sibsp  parch  ticket       fare    cabin embarked boat   body  \
# 2   2.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
# 3  30.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN  135.0
# 4  25.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
# 5  48.0    0.0    0.0   19952   265500.0      E12        S    3    NaN
#
#                          home.dest
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY

# %%
titanic_df.iloc[1:5, 1:3]
# Out:
#    survived                                             name
# 1       1.0                   Allison, Master. Hudson Trevor
# 2       0.0                     Allison, Miss. Helen Loraine
# 3       0.0             Allison, Mr. Hudson Joshua Creighton
# 4       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)

# %%
titanic_df['name'].head()
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %%
titanic_df[ ['name', 'sex', 'parch'] ].head()
# Out:
#                                               name     sex  parch
# 0                    Allen, Miss. Elisabeth Walton  female    0.0
# 1                   Allison, Master. Hudson Trevor    male    2.0
# 2                     Allison, Miss. Helen Loraine  female    2.0
# 3             Allison, Mr. Hudson Joshua Creighton    male    2.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female    2.0

# %%
titanic_df[titanic_df['sex'] == 'female']
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6        1.0       1.0                Andrews, Miss. Kornelia Theodosia
# 8        1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286     3.0       1.0  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290     3.0       1.0                 Wilkes, Mrs. James (Ellen Needs)
# 1300     3.0       1.0          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1305     3.0       0.0                            Zabour, Miss. Thamine
#
#          sex    age  sibsp  parch  ticket       fare    cabin embarked boat  \
# ...

# %%
titanic_df[ (titanic_df['sex'] == 'female') & ( titanic_df['age'] >= 60) | (titanic_df['sex'] == 'male') ].head()
# Out:
#    pclass  survived                                  name     sex     age  \
# 1     1.0       1.0        Allison, Master. Hudson Trevor    male  9167.0
# 3     1.0       0.0  Allison, Mr. Hudson Joshua Creighton    male    30.0
# 5     1.0       1.0                   Anderson, Mr. Harry    male    48.0
# 6     1.0       1.0     Andrews, Miss. Kornelia Theodosia  female    63.0
# 7     1.0       0.0                Andrews, Mr. Thomas Jr    male    39.0
#
#    sibsp  parch  ticket       fare    cabin embarked boat   body  \
# 1    1.0    2.0  113781  1515500.0  C22 C26        S   11    NaN
# 3    1.0    2.0  113781  1515500.0  C22 C26        S  NaN  135.0
# 5    0.0    0.0   19952   265500.0      E12        S    3    NaN
# 6    1.0    0.0   13502   779583.0       D7        S   10    NaN
# 7    0.0    0.0  112050        0.0      A36        S  NaN    NaN
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# ...

# %%
titanic_df[( titanic_df.sex == 'female') &
          (titanic_df.age > 18) &
          (titanic_df.age < 25) &
          (titanic_df.sibsp == 0) &
          (titanic_df.parch == 0)].shape
# Out:
# (40, 14)

# %%
titanic_df.age.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %%
titanic_df.rename( columns = {'sex' : 'Sex'}, inplace = True)
titanic_df.head()
# Out:
#    pclass  survived                                             name     Sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket       fare    cabin embarked boat   body  \
# 0    29.0    0.0    0.0   24160  2113375.0       B5        S    2    NaN
# 1  9167.0    1.0    2.0  113781  1515500.0  C22 C26        S   11    NaN
# 2     2.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
# 3    30.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN  135.0
# 4    25.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
def get_last_name(name):
    return str(name).split(',')[0].strip()

last_names = titanic_df['name'].apply(get_last_name)
last_names
# Out:
# 0           Allen
# 1         Allison
# 2         Allison
# 3         Allison
# 4         Allison
#           ...
# 1305       Zabour
# 1306     Zakarian
# 1307     Zakarian
# 1308    Zimmerman
# 1309          nan
# Name: name, Length: 1310, dtype: object

# %%
titanic_df['Last_name'] = last_names 
titanic_df.head()
# Out:
#    pclass  survived                                             name     Sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket       fare    cabin embarked boat   body  \
# 0    29.0    0.0    0.0   24160  2113375.0       B5        S    2    NaN
# 1  9167.0    1.0    2.0  113781  1515500.0  C22 C26        S   11    NaN
# 2     2.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
# 3    30.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN  135.0
# 4    25.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
#
#                          home.dest Last_name
# ...

# %%
titanic_df.drop('Last_name', axis = 1, inplace = True)
titanic_df.head()
# Out:
#    pclass  survived                                             name     Sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket       fare    cabin embarked boat   body  \
# 0    29.0    0.0    0.0   24160  2113375.0       B5        S    2    NaN
# 1  9167.0    1.0    2.0  113781  1515500.0  C22 C26        S   11    NaN
# 2     2.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
# 3    30.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN  135.0
# 4    25.0    1.0    2.0  113781  1515500.0  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic_df['boat'].isnull().head()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: boat, dtype: bool

# %%
titanic_df[ titanic_df['boat'].notnull()].head()
# Out:
#    pclass  survived                                           name     Sex  \
# 0     1.0       1.0                  Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                 Allison, Master. Hudson Trevor    male
# 5     1.0       1.0                            Anderson, Mr. Harry    male
# 6     1.0       1.0              Andrews, Miss. Kornelia Theodosia  female
# 8     1.0       1.0  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#       age  sibsp  parch  ticket       fare    cabin embarked boat  body  \
# 0    29.0    0.0    0.0   24160  2113375.0       B5        S    2   NaN
# 1  9167.0    1.0    2.0  113781  1515500.0  C22 C26        S   11   NaN
# 5    48.0    0.0    0.0   19952   265500.0      E12        S    3   NaN
# 6    63.0    1.0    0.0   13502   779583.0       D7        S   10   NaN
# 8    53.0    2.0    0.0   11769   514792.0     C101        S    D   NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic_df.sort_values(by = ['pclass', 'fare'], ascending = True).head()
# Out:
#      pclass  survived                                   name   Sex   age  \
# 7       1.0       0.0                 Andrews, Mr. Thomas Jr  male  39.0
# 70      1.0       0.0  Chisholm, Mr. Roderick Robert Crispin  male   NaN
# 125     1.0       0.0                       Fry, Mr. Richard  male   NaN
# 150     1.0       0.0                  Harrison, Mr. William  male  40.0
# 170     1.0       1.0                Ismay, Mr. Joseph Bruce  male  49.0
#
#      sibsp  parch  ticket  fare        cabin embarked boat   body  \
# 7      0.0    0.0  112050   0.0          A36        S  NaN    NaN
# 70     0.0    0.0  112051   0.0          NaN        S  NaN    NaN
# 125    0.0    0.0  112058   0.0         B102        S  NaN    NaN
# 150    0.0    0.0  112059   0.0          B94        S  NaN  110.0
# 170    0.0    0.0  112058   0.0  B52 B54 B56        S    C    NaN
#
#                         home.dest
# 7                     Belfast, NI
# 70   Liverpool, England / Belfast
# ...

# %%
titanic_df.sort_values(by = ['pclass', 'fare'], ascending = [True, False]).head()
# Out:
#      pclass  survived                                               name  \
# 49      1.0       1.0                 Cardeza, Mr. Thomas Drake Martinez
# 50      1.0       1.0  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 183     1.0       1.0                             Lesurer, Mr. Gustave J
# 302     1.0       1.0                                   Ward, Miss. Anna
# 111     1.0       1.0                     Fortune, Miss. Alice Elizabeth
#
#         Sex   age  sibsp  parch    ticket       fare        cabin embarked  \
# 49     male  36.0    0.0    1.0  PC 17755  5123292.0  B51 B53 B55        C
# 50   female  58.0    0.0    1.0  PC 17755  5123292.0  B51 B53 B55        C
# 183    male  35.0    0.0    0.0  PC 17755  5123292.0         B101        C
# 302  female  35.0    0.0    0.0  PC 17755  5123292.0          NaN        C
# 111  female  24.0    3.0    2.0     19950  2630000.0  C23 C25 C27        S
#
#     boat  body                                       home.dest
# ...

# %%
titanic_df.groupby('Sex')

# %%
titanic_df.groupby('Sex')['pclass'].value_counts()
# Out:
# Sex     pclass
# female  3.0       216
#         1.0       144
#         2.0       106
# male    3.0       493
#         1.0       179
#         2.0       171
# Name: pclass, dtype: int64

# %%
titanic_df.groupby('pclass')['fare'].describe()
# Out:
#         count           mean            std  min       25%       50%  \
# pclass
# 1.0     323.0  875089.916409  804471.782489  0.0  306958.0  600000.0
# 2.0     277.0  211791.963899  136071.220555  0.0  130000.0  150458.0
# 3.0     708.0  133028.887006  114943.584534  0.0   77500.0   80500.0
#
#               75%        max
# pclass
# 1.0     1076625.0  5123292.0
# 2.0      260000.0   735000.0
# 3.0      152458.0   695500.0

# %%
titanic_df.groupby('Sex')['age'].mean()
# Out:
# Sex
# female     59.216495
# male      117.460486
# Name: age, dtype: float64

# %%
titanic_df.groupby('Sex')['survived'].mean()
# Out:
# Sex
# female    0.727468
# male      0.190985
# Name: survived, dtype: float64

# %%
titanic_df.groupby('pclass')['survived'].mean()
# Out:
# pclass
# 1.0    0.619195
# 2.0    0.429603
# 3.0    0.255289
# Name: survived, dtype: float64

# %%
titanic_df.groupby('Sex', as_index = False)['survived'].mean()
# Out:
#       Sex  survived
# 0  female  0.727468
# 1    male  0.190985
