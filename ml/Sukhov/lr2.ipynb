# %%
import numpy as np

# %%
import pandas as pd

# %%
flights_df = pd.read_csv('flights.csv', sep = ',', nrows = 1000)

# %%
flights_df
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0    2015      1    1            4      AS             98      N407AS
# 1    2015      1    1            4      AA           2336      N3KUAA
# 2    2015      1    1            4      US            840      N171US
# 3    2015      1    1            4      AA            258      N3HYAA
# 4    2015      1    1            4      AS            135      N527AS
# 5    2015      1    1            4      DL            806      N3730B
# 6    2015      1    1            4      NK            612      N635NK
# 7    2015      1    1            4      US           2013      N584UW
# 8    2015      1    1            4      AA           1112      N3LAAA
# 9    2015      1    1            4      DL           1173      N826DN
# 10   2015      1    1            4      DL           2336      N958DN
# 11   2015      1    1            4      AA           1674      N853AA
# ...

# %%
flights_df.groupby(['CANCELLED', 'CANCELLATION_REASON'])['YEAR'].count() #Количество отменённых рейсов
# Out:
# CANCELLED  CANCELLATION_REASON
# 1          A                      11
#            B                      72
#            C                       1
# Name: YEAR, dtype: int64

# %%
pd.set_option('display.max_rows', None)
flights_df.groupby(['CANCELLED', 'ORIGIN_AIRPORT'])['YEAR'].count() #Аэропортом, рейсы для которого отменяются наиболее часто, является DFW
# Out:
# CANCELLED  ORIGIN_AIRPORT
# 0          ABE                2
#            ABQ                3
#            ABR                1
#            ACV                1
#            ACY                3
#            ALB                2
#            ANC               12
#            ASE                1
#            ATL                8
#            ATW                2
#            AUS                8
#            AVL                1
#            BDL                6
#            BFL                3
#            BHM                3
#            BIS                1
#            BJI                1
#            BLI                1
#            BNA                7
#            BOI                5
#            BOS               37
#            BPT                1
#            BQN                4
#            BRO                2
#            BTR                3
#            BTV                2
#            BUF                5
#            BUR                2
# ...

# %%
flights_df.groupby(['AIRLINE', 'CANCELLED'])['YEAR'].count()#Количество отменённых рейсов для авиакомпаний
# Out:
# AIRLINE  CANCELLED
# AA       0            113
#          1             22
# AS       0             59
#          1              1
# B6       0             91
# DL       0            118
# EV       0             77
#          1              1
# F9       0             32
#          1              2
# HA       0             17
# MQ       0             19
#          1             49
# NK       0             40
# OO       0            113
#          1              8
# UA       0            103
# US       0             59
# VX       0              4
# WN       0             71
#          1              1
# Name: YEAR, dtype: int64

# %%
flights_df['SPEED'] = flights_df['DISTANCE'] / flights_df['ELAPSED_TIME'] #Добавление нового столбца "скорость"
flights_df[['FLIGHT_NUMBER', 'SPEED']] #Вывод скорости для каждого рейса
# Out:
#      FLIGHT_NUMBER     SPEED
# 0               98  7.463918
# 1             2336  8.351254
# 2              840  7.836177
# 3              258  8.334520
# 4              135  6.734884
# 5              806  6.908696
# 6              612  7.641176
# 7             2013  8.534137
# 8             1112  7.585492
# 9             1173  8.605911
# 10            2336  8.046980
# 11            1674  8.172932
# 12            1434  7.309524
# 13            2324  7.989950
# 14            2440  7.065657
# 15             108  7.463918
# 16            1560  7.240000
# 17            1197  7.534562
# 18             122  7.671642
# 19            1670  7.666667
# 20             520  7.965035
# 21             371  7.850144
# 22             214  7.176871
# 23             115  8.485507
# 24            1450  7.969325
# 25            1545  7.880000
# 26             130  7.032110
# 27             597  6.759091
# 28             413  8.553571
# 29            2392  8.216346
# 30             168  8.228571
# ...

# %%
flights_df.groupby('AIRLINE')['SPEED'].mean().sample(3) #Средняя скорость полёта для трёх выбранных авиакомпаний
# Out:
# AIRLINE
# UA    6.297580
# US    5.606486
# OO    4.291334
# Name: SPEED, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
flights_df.corr()
# Out:
#                      YEAR  MONTH  DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# YEAR                  NaN    NaN  NaN          NaN            NaN
# MONTH                 NaN    NaN  NaN          NaN            NaN
# DAY                   NaN    NaN  NaN          NaN            NaN
# DAY_OF_WEEK           NaN    NaN  NaN          NaN            NaN
# FLIGHT_NUMBER         NaN    NaN  NaN          NaN       1.000000
# SCHEDULED_DEPARTURE   NaN    NaN  NaN          NaN       0.065010
# DEPARTURE_TIME        NaN    NaN  NaN          NaN       0.043470
# DEPARTURE_DELAY       NaN    NaN  NaN          NaN       0.010928
# TAXI_OUT              NaN    NaN  NaN          NaN       0.236016
# WHEELS_OFF            NaN    NaN  NaN          NaN       0.076614
# SCHEDULED_TIME        NaN    NaN  NaN          NaN      -0.357823
# ELAPSED_TIME          NaN    NaN  NaN          NaN      -0.330025
# AIR_TIME              NaN    NaN  NaN          NaN      -0.354226
# ...

# %%
sns.heatmap(flights_df[['DAY', 'FLIGHT_NUMBER']].corr())
# Out:
# <AxesSubplot:>

# %%
flights_df[(flights_df['ORIGIN_AIRPORT'] == 'ABE') | (flights_df['ORIGIN_AIRPORT'] == 'ABR') | (flights_df['ORIGIN_AIRPORT'] == 'ABQ')]
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 67   2015      1    1            4      OO           7419      N445SW
# 186  2015      1    1            4      WN           2215      N249WN
# 288  2015      1    1            4      EV           5103      N846AS
# 656  2015      1    1            4      EV           5579      N136EV
# 799  2015      1    1            4      WN            897      N427WN
# 820  2015      1    1            4      MQ           3188      N507MQ
#
#     ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 67             ABR                 MSP                  510  ...
# 186            ABQ                 HOU                  600  ...
# 288            ABE                 DTW                  600  ...
# 656            ABE                 ATL                  635  ...
# 799            ABQ                 DAL                  655  ...
# 820            ABQ                 ORD                  655  ...
#
# ...

# %%
flights_df.groupby('ORIGIN_AIRPORT')['DEPARTURE_DELAY'].mean().tail(3) #Время задержки отправки для 3 аэропортов
# Out:
# ORIGIN_AIRPORT
# TYS    -4.0
# VPS    -4.5
# XNA    10.0
# Name: DEPARTURE_DELAY, dtype: float64

# %%
flights_df.groupby('ORIGIN_AIRPORT')['ARRIVAL_DELAY'].mean().tail(3) #Время задержки прибытия для 3 аэропортов
# Out:
# ORIGIN_AIRPORT
# TYS     4.0
# VPS    -9.0
# XNA   -10.0
# Name: ARRIVAL_DELAY, dtype: float64

# %%
flights_df[(flights_df['AIR_SYSTEM_DELAY'] > 0) & ((flights_df['DESTINATION_AIRPORT'] == 'FLL') | (flights_df['DESTINATION_AIRPORT'] == 'MCO') | (flights_df['DESTINATION_AIRPORT'] == 'BDL'))]
# Задержка воздушной системы для аэропортов FFL, MCO, BDL
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 27   2015      1    1            4      NK            597      N528NK
# 50   2015      1    1            4      B6           1030      N239JB
# 55   2015      1    1            4      B6           2276      N646JB
# 329  2015      1    1            4      NK            972      N606NK
# 446  2015      1    1            4      B6           1554      N760JB
# 697  2015      1    1            4      NK            705      N588NK
# 959  2015      1    1            4      NK            231      N620NK
# 963  2015      1    1            4      NK            198      N621NK
#
#     ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 27             MSP                 FLL                  115  ...
# 50             BQN                 MCO                  307  ...
# 55             SJU                 BDL                  438  ...
# 329            DFW                 FLL                  600  ...
# ...

# %%
flights_df[(flights_df['SECURITY_DELAY'] > 0) & ((flights_df['DESTINATION_AIRPORT'] == 'FLL') | (flights_df['DESTINATION_AIRPORT'] == 'MCO') | (flights_df['DESTINATION_AIRPORT'] == 'BDL'))]
# Задержка безопасности для аэропортов FFL, MCO, BDL
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, DAY, DAY_OF_WEEK, AIRLINE, FLIGHT_NUMBER, TAIL_NUMBER, ORIGIN_AIRPORT, DESTINATION_AIRPORT, SCHEDULED_DEPARTURE, DEPARTURE_TIME, DEPARTURE_DELAY, TAXI_OUT, WHEELS_OFF, SCHEDULED_TIME, ELAPSED_TIME, AIR_TIME, DISTANCE, WHEELS_ON, TAXI_IN, SCHEDULED_ARRIVAL, ARRIVAL_TIME, ARRIVAL_DELAY, DIVERTED, CANCELLED, CANCELLATION_REASON, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY, SPEED]
# Index: []
#
# [0 rows x 32 columns]

# %%
flights_df[(flights_df['AIRLINE_DELAY'] > 0) & ((flights_df['DESTINATION_AIRPORT'] == 'FLL') | (flights_df['DESTINATION_AIRPORT'] == 'MCO') | (flights_df['DESTINATION_AIRPORT'] == 'BDL'))]
# Задержка авиалиний для аэропортов FFL, MCO, BDL
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 52   2015      1    1            4      B6           2134      N307JB
# 55   2015      1    1            4      B6           2276      N646JB
# 446  2015      1    1            4      B6           1554      N760JB
# 941  2015      1    1            4      AA           2393      N3APAA
# 950  2015      1    1            4      F9            676      N908FR
#
#     ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 52             SJU                 MCO                  400  ...
# 55             SJU                 BDL                  438  ...
# 446            SJU                 FLL                  610  ...
# 941            JFK                 MCO                  700  ...
# 950            DEN                 MCO                  700  ...
#
#      ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 52            85.0         0          0                  NaN
# ...

# %%
flights_df[(flights_df['LATE_AIRCRAFT_DELAY'] > 0) & ((flights_df['DESTINATION_AIRPORT'] == 'FLL') | (flights_df['DESTINATION_AIRPORT'] == 'MCO') | (flights_df['DESTINATION_AIRPORT'] == 'BDL'))]
# Поздняя задержка воздушного судна для аэропортов FFL, MCO, BDL
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 398  2015      1    1            4      B6           1434      N503JB
#
#     ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 398            SJU                 MCO                  605  ...
#
#      ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 398           88.0         0          0                  NaN
#
#      AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 398               0.0             0.0            0.0                 88.0
#
#      WEATHER_DELAY     SPEED
# 398            0.0  6.497268
#
# [1 rows x 32 columns]

# %%
flights_df[(flights_df['WEATHER_DELAY'] > 0) & ((flights_df['DESTINATION_AIRPORT'] == 'FLL') | (flights_df['DESTINATION_AIRPORT'] == 'MCO') | (flights_df['DESTINATION_AIRPORT'] == 'BDL'))]
# Задержка из-за погоды для аэропортов FFL, MCO, BDL
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, DAY, DAY_OF_WEEK, AIRLINE, FLIGHT_NUMBER, TAIL_NUMBER, ORIGIN_AIRPORT, DESTINATION_AIRPORT, SCHEDULED_DEPARTURE, DEPARTURE_TIME, DEPARTURE_DELAY, TAXI_OUT, WHEELS_OFF, SCHEDULED_TIME, ELAPSED_TIME, AIR_TIME, DISTANCE, WHEELS_ON, TAXI_IN, SCHEDULED_ARRIVAL, ARRIVAL_TIME, ARRIVAL_DELAY, DIVERTED, CANCELLED, CANCELLATION_REASON, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY, SPEED]
# Index: []
#
# [0 rows x 32 columns]

# %%
flights_df.groupby(['AIRLINE','DEPARTURE_DELAY'])['YEAR'].count()
# Out:
# AIRLINE  DEPARTURE_DELAY
# AA       -12.0               1
#          -11.0               3
#          -10.0               1
#          -9.0                2
#          -8.0               12
#          -7.0                7
#          -6.0               10
#          -5.0               10
#          -4.0               14
#          -3.0                9
#          -2.0                6
#          -1.0                5
#           0.0                4
#           1.0                2
#           3.0                3
#           4.0                2
#           5.0                1
#           6.0                2
#           10.0               2
#           11.0               1
#           13.0               1
#           21.0               2
#           29.0               1
#           33.0               1
#           43.0               1
#           45.0               1
#           53.0               1
#           55.0               1
#           58.0               1
# ...

# %%
max_dep = flights_df['DEPARTURE_DELAY'].max()

# %%
max_dep
# Out:
# 364.0

# %%
flights_df[flights_df['DEPARTURE_DELAY'] == flights_df['DEPARTURE_DELAY'].max()]
# Авиакомпания с максимальной задержкой по отправке - EV
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 484  2015      1    1            4      EV           2522      N879AS
#
#     ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 484            LAW                 DFW                  615  ...
#
#      ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 484          376.0         0          0                  NaN
#
#      AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 484              12.0             0.0          364.0                  0.0
#
#      WEATHER_DELAY     SPEED
# 484            0.0  2.089552
#
# [1 rows x 32 columns]

# %%
max_arr = flights_df['ARRIVAL_DELAY'].max()
max_arr
# Out:
# 376.0

# %%
flights_df[flights_df['ARRIVAL_DELAY'] == flights_df['ARRIVAL_DELAY'].max()]
# Авиакомпания с максимальной задержкой по прибитию - EV
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 484  2015      1    1            4      EV           2522      N879AS
#
#     ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 484            LAW                 DFW                  615  ...
#
#      ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 484          376.0         0          0                  NaN
#
#      AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 484              12.0             0.0          364.0                  0.0
#
#      WEATHER_DELAY     SPEED
# 484            0.0  2.089552
#
# [1 rows x 32 columns]
