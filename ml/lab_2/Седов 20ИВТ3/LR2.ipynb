# %% [markdown]
# # Лабораторная работа №2
# ## Седов Артем 20-ИВТ-3
# ### Вариант №3

# %% [markdown]
# ### 1)Удалите столбцы, ценность которых для оценки стоимости машины низка.

# %%
import numpy as np

# %%
import pandas as  pd

# %%
df = pd.read_csv('cnt_km_year_powerPS_minPrice_maxPrice_avgPrice_sdPrice.csv', encoding='iso-8859-1')
                
df
# Out:
#       count      km  year  powerPS  minPrice  maxPrice    avgPrice  \
# 0        19  125000  1991       40       300      1499    648.3158
# 1        69  150000  1991       40       110      1600    516.4348
# 2        11   90000  1991       60       330     10000   2342.4545
# 3        26  100000  1991       60       200      8750   1392.3846
# 4        42  125000  1991       60       150      4600   1140.6429
# ...     ...     ...   ...      ...       ...       ...         ...
# 1765     24   20000  2015      260     25490     73000  49492.3750
# 1766     16   10000  2015      300       699     60000  38542.6875
# 1767     25   20000  2015      300       487     82700  39683.3200
# 1768     22   10000  2015      320     33000     68450  50372.6364
# 1769     16   20000  2015      320     33950     85800  58096.2500
#
#            sdPrice
# 0       352.035293
# 1       346.767661
# 2      3017.432333
# 3      1598.662833
# 4      1010.314138
# ...            ...
# ...

# %%
df = pd.read_csv('autos.csv', encoding='iso-8859-1')
df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.drop(['seller', 'offerType', 'abtest', 'dateCrawled', 'nrOfPictures', 'lastSeen', 'postalCode', 'dateCreated'],axis='columns')
# Out:
#                                                 name  price vehicleType  \
# 0                                         Golf_3_1.6    480         NaN
# 1                               A5_Sportback_2.7_Tdi  18300       coupe
# 2                     Jeep_Grand_Cherokee_"Overland"   9800         suv
# 3                                 GOLF_4_1_4__3TÜRER   1500  kleinwagen
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic   3600  kleinwagen
# ...                                              ...    ...         ...
# 371523                    Suche_t4___vito_ab_6_sitze   2200         NaN
# 371524         Smart_smart_leistungssteigerung_100ps   1199      cabrio
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2   9200         bus
# 371526                        VW_Golf_Kombi_1_9l_TDI   3400       kombi
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro  28990   limousine
#
#         yearOfRegistration    gearbox  powerPS        model  kilometer  \
# ...

# %% [markdown]
# ### 2. Удалите повторяющиеся строки, строки содержащие пропуски в данных. Выведите размер набора данных до и после удаления.

# %%
df.dropna()
df.drop_duplicates()
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
print (" количество автомобилей",df.shape[0] + 1)
# Out:
#  количество автомобилей 371529

# %% [markdown]
# ### 3. Удалите данные в строках, выходящие за некоторые пределы (год регистрации, цена, мощность двигателя). Выведите размер набора данных до и после удаления. Для оценки диапазонов значений признаков используйте BoxPlot.

# %%
boxplot1 = df.boxplot(column=['yearOfRegistration'])

# %%
boxplot2 = df.boxplot(column=['price'])

# %%
boxplot3 = df.boxplot(column=['powerPS'])

# %%
print ("Количество автомобилей начальное", df.shape[0] )
# Out:
# Количество автомобилей начальное 371528

# %%
Cars = df[
        (df.yearOfRegistration <= 2015) 
      & (df.yearOfRegistration >= 1950) 
      & (df.price >= 100) 
      & (df.price <= 150000) 
      & (df.powerPS >= 10) 
      & (df.powerPS <= 500)]

df=Cars
df
# Out:
#                 dateCrawled  \
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# ...                     ...
# 371520  2016-03-19 19:53:49
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371526  2016-03-20 19:41:08
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 2                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...                                                   ...     ...       ...
# 371520                                       turbo_defekt  privat   Angebot
# ...

# %%
print ("Количество автомобилей после манипуляций", df.shape[0] )
# Out:
# Количество автомобилей после манипуляций 304484

# %% [markdown]
# ### 4. Заполнить пропущенные данные в строковых полях.

# %%
df.isnull().sum()
# Out:
# dateCrawled                0
# name                       0
# seller                     0
# offerType                  0
# price                      0
# abtest                     0
# vehicleType             4739
# yearOfRegistration         0
# gearbox                 4882
# powerPS                    0
# model                  10662
# kilometer                  0
# monthOfRegistration        0
# fuelType               12936
# brand                      0
# notRepairedDamage      40410
# dateCreated                0
# nrOfPictures               0
# postalCode                 0
# lastSeen                   0
# dtype: int64

# %%
df['notRepairedDamage'].fillna(value='not-declared', inplace=True)
df['fuelType'].fillna(value='not-declared', inplace=True)
df['gearbox'].fillna(value='not-declared', inplace=True)
df['vehicleType'].fillna(value='not-declared', inplace=True)
df['model'].fillna(value='not-declared', inplace=True)

df.isnull().sum()
# Out:
# C:\Users\xxdeal\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# nrOfPictures           0
# postalCode             0
# lastSeen               0
# dtype: int64

# %% [markdown]
# ### 5. Постройте гистограмму по маркам автомобилей, типам кузова и используемому топливу.

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
categories = ['brand', 'vehicleType', 'fuelType']
for i, c in enumerate(categories):
    v = df[c].unique()
    g = df.groupby(by=c)[c].count().sort_values(ascending=False)
    r = range(min(len(v), 5))
    print( g.head())
    plt.figure(figsize=(5,3))
    plt.bar(r, g.head())
   # plt.xticks(r, g.index)
 
    plt.show()
# Out:
# brand
# volkswagen       64574
# bmw              34884
# opel             31558
# mercedes_benz    29824
# audi             28400
# Name: brand, dtype: int64
# vehicleType
# limousine     86990
# kleinwagen    69676
# kombi         61374
# bus           27503
# cabrio        21226
# Name: vehicleType, dtype: int64
# fuelType
# benzin          190487
# diesel           95510
# not-declared     12936
# lpg               4681
# cng                480
# Name: fuelType, dtype: int64

# %% [markdown]
# ### 6. Добавьте в данные новый признак, который представляет собой длину названия автомобиля.

# %%
df['Longname'] = [len(n) for n in df['name']]
df
# Out:
# C:\Users\xxdeal\AppData\Local\Temp/ipykernel_18952/720215982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Longname'] = [len(n) for n in df['name']]
#                 dateCrawled  \
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# ...                     ...
# 371520  2016-03-19 19:53:49
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371526  2016-03-20 19:41:08
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# ...

# %% [markdown]
# ### 7. Постройте карту корреляций между признаками. Выведите также числовые значения признаков.

# %%
import seaborn as sns


plt.figure(figsize=(20,20), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='magma', center=0, annot=True)


plt.title('Correlation map', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

df.corr()
# Out:
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000            0.421323  0.573451  -0.442688
# yearOfRegistration   0.421323            1.000000  0.214146  -0.360824
# powerPS              0.573451            0.214146  1.000000  -0.014495
# kilometer           -0.442688           -0.360824 -0.014495   1.000000
# monthOfRegistration  0.045533            0.060233  0.038301  -0.018782
# nrOfPictures              NaN                 NaN       NaN        NaN
# postalCode           0.075652            0.046232  0.065655  -0.030454
# Longname             0.038739            0.037994  0.021772  -0.020475
#
#                      monthOfRegistration  nrOfPictures  postalCode  Longname
# price                           0.045533           NaN    0.075652  0.038739
# yearOfRegistration              0.060233           NaN    0.046232  0.037994
# powerPS                         0.038301           NaN    0.065655  0.021772
# ...

# %% [markdown]
# ### 8. Определите коэффициент корреляции Пирсона и Спирмена между стоимостью автомобиля и мощностью двигателя. Оцените значение p-value. Постройте плотность распределения признаков.

# %%
spearman = df['powerPS'].corr(df['price'], method="spearman")
pearson = df['powerPS'].corr(df['price'], method="pearson")

# %%
print("Корреляция между powerPS и price равна:")
print("Методом Пирсона: ", pearson)
print('Методом Спирмена:', spearman)

if (pearson > spearman):
    print("Число Пирсона больше числа Спирмена")
elif (pearson < spearman):
    print("Число Спирмена больше числа Пирсона")
else:
    print("Число Спирмена и число Пирсона одинакова")
    
print("Разница:", abs(pearson - spearman))
# Out:
# Корреляция между powerPS и price равна:
# Методом Пирсона:  0.5734507410068155
# Методом Спирмена: 0.5726627266664795
# Число Пирсона больше числа Спирмена
# Разница: 0.0007880143403359297

# %%
df['vehicleType'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 9. Добавьте в набор данных признак, являющийся суммой двух других признаков.

# %%
df['gearbox+model'] = [n for n in (df['gearbox'] + " " + df['model']) ]
df
# Out:
# C:\Users\xxdeal\AppData\Local\Temp/ipykernel_18952/3076808849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gearbox+model'] = [n for n in (df['gearbox'] + " " + df['model']) ]
#                 dateCrawled  \
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# ...                     ...
# 371520  2016-03-19 19:53:49
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371526  2016-03-20 19:41:08
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# ...
