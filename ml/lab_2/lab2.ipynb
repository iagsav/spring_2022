# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
autos = pd.read_csv('autos.csv', encoding='iso-8859-1')
autos
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
autos.size
# Out:
# 7430560

# %%
autos.drop('nrOfPictures', axis = 1, inplace = True)
autos.drop('postalCode', axis = 1, inplace = True)
autos.drop('lastSeen', axis = 1, inplace = True)
autos
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
autos.size
# Out:
# 6315976

# %%
autos.drop_duplicates(keep = 'first', inplace = True )
autos
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
autos.size
# Out:
# 6315755

# %%
autos.dropna(axis = 0, inplace = True)
autos
# Out:
#                 dateCrawled  \
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# ...                     ...
# 371520  2016-03-19 19:53:49
# 371521  2016-03-27 20:36:20
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 6                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 7                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# ...                                                   ...     ...       ...
# 371520                                       turbo_defekt  privat   Angebot
# ...

# %%
autos.size
# Out:
# 4436031

# %%
autos.boxplot('price')
# Out:
# <AxesSubplot:>

# %%
autos.boxplot('powerPS')
# Out:
# <AxesSubplot:>

# %%
autos.boxplot('yearOfRegistration')
# Out:
# <AxesSubplot:>

# %%
autos.loc[(autos.yearOfRegistration > 2011), 'yearOfRegistration'] = float('nan')
autos.loc[(autos.yearOfRegistration < 2006), 'yearOfRegistration'] = float('nan')

autos.loc[(autos.powerPS > 85), 'powerPS'] = float('nan')
autos.loc[(autos.powerPS < 65), 'powerPS'] = float('nan')

autos.loc[(autos.price > 10000), 'price'] = float('nan')
autos.loc[(autos.price < 1000), 'price'] = float('nan')

autos
# Out:
#                 dateCrawled  \
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# ...                     ...
# 371520  2016-03-19 19:53:49
# 371521  2016-03-27 20:36:20
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 6                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 7                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# ...                                                   ...     ...       ...
# 371520                                       turbo_defekt  privat   Angebot
# ...

# %%
autos.size
# Out:
# 4436031

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values = np.nan, strategy = "most_frequent")
autos = pd.DataFrame(imp.fit_transform(autos), columns=autos.columns).astype(autos.dtypes.to_dict())

autos.columns = autos.columns
autos.index   = autos.index

autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260943 entries, 0 to 260942
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          260943 non-null  object
#  1   name                 260943 non-null  object
#  2   seller               260943 non-null  object
#  3   offerType            260943 non-null  object
#  4   price                260943 non-null  float64
#  5   abtest               260943 non-null  object
#  6   vehicleType          260943 non-null  object
#  7   yearOfRegistration   260943 non-null  float64
#  8   gearbox              260943 non-null  object
#  9   powerPS              260943 non-null  float64
#  10  model                260943 non-null  object
#  11  kilometer            260943 non-null  int64
#  12  monthOfRegistration  260943 non-null  int64
#  13  fuelType             260943 non-null  object
#  14  brand                260943 non-null  object
# ...

# %%
autos.size
# Out:
# 4436031

# %%
autos.loc[(autos.fuelType == 'benzin'), 'fuelType'] = 'petrol'
autos.loc[(autos.fuelType == 'elektro'), 'fuelType'] = 'electro'
autos.loc[(autos.notRepairedDamage == 'ja'), 'notRepairedDamage'] = 'yes'
autos.loc[(autos.notRepairedDamage == 'nein'), 'notRepairedDamage'] = 'no'
autos
# Out:
#                 dateCrawled  \
# 0       2016-03-17 16:54:04
# 1       2016-03-31 17:25:20
# 2       2016-04-04 17:36:23
# 3       2016-04-01 20:48:51
# 4       2016-03-21 18:54:38
# ...                     ...
# 260938  2016-03-19 19:53:49
# 260939  2016-03-27 20:36:20
# 260940  2016-03-05 19:56:21
# 260941  2016-03-19 18:57:12
# 260942  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 0                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 1                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 2       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 3                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 4                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# ...                                                   ...     ...       ...
# 260938                                       turbo_defekt  privat   Angebot
# ...

# %%
autos.fuelType.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
autos.vehicleType.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
autos['nameL'] = autos['name'].str.len()
autos
# Out:
#                 dateCrawled  \
# 0       2016-03-17 16:54:04
# 1       2016-03-31 17:25:20
# 2       2016-04-04 17:36:23
# 3       2016-04-01 20:48:51
# 4       2016-03-21 18:54:38
# ...                     ...
# 260938  2016-03-19 19:53:49
# 260939  2016-03-27 20:36:20
# 260940  2016-03-05 19:56:21
# 260941  2016-03-19 18:57:12
# 260942  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 0                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 1                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 2       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 3                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 4                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# ...                                                   ...     ...       ...
# 260938                                       turbo_defekt  privat   Angebot
# ...

# %%
autos.corr()
# Out:
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000            0.173231  0.004961  -0.050702
# yearOfRegistration   0.173231            1.000000 -0.024649  -0.250813
# powerPS              0.004961           -0.024649  1.000000   0.048209
# kilometer           -0.050702           -0.250813  0.048209   1.000000
# monthOfRegistration  0.034647            0.024334  0.006001  -0.006263
# nameL                0.014062            0.046631  0.006135  -0.038740
#
#                      monthOfRegistration     nameL
# price                           0.034647  0.014062
# yearOfRegistration              0.024334  0.046631
# powerPS                         0.006001  0.006135
# kilometer                      -0.006263 -0.038740
# monthOfRegistration             1.000000  0.007100
# nameL                           0.007100  1.000000

# %%
cars = pd.read_csv('cnt_km_year_powerPS_minPrice_maxPrice_avgPrice_sdPrice.csv', encoding='iso-8859-1')
cars
# Out:
#       count      km  year  powerPS  minPrice  maxPrice    avgPrice  \
# 0        19  125000  1991       40       300      1499    648.3158
# 1        69  150000  1991       40       110      1600    516.4348
# 2        11   90000  1991       60       330     10000   2342.4545
# 3        26  100000  1991       60       200      8750   1392.3846
# 4        42  125000  1991       60       150      4600   1140.6429
# ...     ...     ...   ...      ...       ...       ...         ...
# 1765     24   20000  2015      260     25490     73000  49492.3750
# 1766     16   10000  2015      300       699     60000  38542.6875
# 1767     25   20000  2015      300       487     82700  39683.3200
# 1768     22   10000  2015      320     33000     68450  50372.6364
# 1769     16   20000  2015      320     33950     85800  58096.2500
#
#            sdPrice
# 0       352.035293
# 1       346.767661
# 2      3017.432333
# 3      1598.662833
# 4      1010.314138
# ...            ...
# ...

# %%
autos.corr()
# Out:
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000            0.173231  0.004961  -0.050702
# yearOfRegistration   0.173231            1.000000 -0.024649  -0.250813
# powerPS              0.004961           -0.024649  1.000000   0.048209
# kilometer           -0.050702           -0.250813  0.048209   1.000000
# monthOfRegistration  0.034647            0.024334  0.006001  -0.006263
# nameL                0.014062            0.046631  0.006135  -0.038740
# sum                  1.000000            0.173213  0.005660  -0.050668
#
#                      monthOfRegistration     nameL       sum
# price                           0.034647  0.014062  1.000000
# yearOfRegistration              0.024334  0.046631  0.173213
# powerPS                         0.006001  0.006135  0.005660
# kilometer                      -0.006263 -0.038740 -0.050668
# monthOfRegistration             1.000000  0.007100  0.034651
# ...

# %%
autos[['price', 'powerPS']].corr('pearson')
# Out:
#             price   powerPS
# price    1.000000  0.004961
# powerPS  0.004961  1.000000

# %%
autos[['price', 'powerPS']].corr('spearman')
# Out:
#             price   powerPS
# price    1.000000 -0.002073
# powerPS -0.002073  1.000000

# %%
autos.corr('pearson')
# Out:
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000            0.173231  0.004961  -0.050702
# yearOfRegistration   0.173231            1.000000 -0.024649  -0.250813
# powerPS              0.004961           -0.024649  1.000000   0.048209
# kilometer           -0.050702           -0.250813  0.048209   1.000000
# monthOfRegistration  0.034647            0.024334  0.006001  -0.006263
# nameL                0.014062            0.046631  0.006135  -0.038740
# sum                  1.000000            0.173213  0.005660  -0.050668
#
#                      monthOfRegistration     nameL       sum
# price                           0.034647  0.014062  1.000000
# yearOfRegistration              0.024334  0.046631  0.173213
# powerPS                         0.006001  0.006135  0.005660
# kilometer                      -0.006263 -0.038740 -0.050668
# monthOfRegistration             1.000000  0.007100  0.034651
# ...

# %%
autos.corr('spearman')
# Out:
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000            0.167774 -0.002073  -0.028432
# yearOfRegistration   0.167774            1.000000 -0.015852  -0.275429
# powerPS             -0.002073           -0.015852  1.000000   0.045650
# kilometer           -0.028432           -0.275429  0.045650   1.000000
# monthOfRegistration  0.037079            0.028430  0.007560  -0.009549
# nameL                0.037722            0.124779  0.014680  -0.101819
# sum                  0.997485            0.168508  0.028695  -0.028657
#
#                      monthOfRegistration     nameL       sum
# price                           0.037079  0.037722  0.997485
# yearOfRegistration              0.028430  0.124779  0.168508
# powerPS                         0.007560  0.014680  0.028695
# kilometer                      -0.009549 -0.101819 -0.028657
# monthOfRegistration             1.000000  0.029079  0.037340
# ...

# %%
import seaborn as sns
sns.distplot(autos['price'], hist = False, kde = True)
# Out:
# C:\Users\Max\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
autos['sum'] = autos['price']+autos['powerPS']
autos
# Out:
#                 dateCrawled  \
# 0       2016-03-17 16:54:04
# 1       2016-03-31 17:25:20
# 2       2016-04-04 17:36:23
# 3       2016-04-01 20:48:51
# 4       2016-03-21 18:54:38
# ...                     ...
# 260938  2016-03-19 19:53:49
# 260939  2016-03-27 20:36:20
# 260940  2016-03-05 19:56:21
# 260941  2016-03-19 18:57:12
# 260942  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 0                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 1                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 2       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 3                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 4                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# ...                                                   ...     ...       ...
# 260938                                       turbo_defekt  privat   Angebot
# ...

# %%
# %matplotlib inline
autos['brand']
# Out:
# 0         volkswagen
# 1              skoda
# 2                bmw
# 3            peugeot
# 4         volkswagen
#              ...
# 260938          seat
# 260939          opel
# 260940         smart
# 260941    volkswagen
# 260942           bmw
# Name: brand, Length: 260943, dtype: object

# %%
names = autos['brand']
names
# Out:
# 0         volkswagen
# 1              skoda
# 2                bmw
# 3            peugeot
# 4         volkswagen
#              ...
# 260938          seat
# 260939          opel
# 260940         smart
# 260941    volkswagen
# 260942           bmw
# Name: brand, Length: 260943, dtype: object

# %%
slovar = {}
for i in names : 
    if i in slovar : 
        slovar[i] += 1
    else :
        slovar[i] = 0
        
slovar
# Out:
# {'volkswagen': 54188,
#  'skoda': 4535,
#  'bmw': 30330,
#  'peugeot': 7850,
#  'mazda': 4038,
#  'nissan': 3593,
#  'renault': 11670,
#  'ford': 17445,
#  'mercedes_benz': 26902,
#  'seat': 5016,
#  'honda': 1945,
#  'fiat': 6363,
#  'mini': 2876,
#  'opel': 26389,
#  'smart': 3351,
#  'audi': 24771,
#  'alfa_romeo': 1703,
#  'subaru': 549,
#  'mitsubishi': 2074,
#  'hyundai': 2785,
#  'volvo': 2587,
#  'lancia': 319,
#  'porsche': 1865,
#  'citroen': 3689,
#  'toyota': 3702,
#  'kia': 1969,
#  'chevrolet': 1347,
#  'dacia': 722,
#  'suzuki': 1681,
#  'daihatsu': 519,
#  'chrysler': 1024,
#  'jaguar': 486,
#  'rover': 261,
#  'jeep': 615,
#  'saab': 420,
#  'daewoo': 336,
#  'land_rover': 634,
#  'trabant': 210,
#  'lada': 145}

# %%
slovar.keys()
# Out:
# dict_keys(['volkswagen', 'skoda', 'bmw', 'peugeot', 'mazda', 'nissan', 'renault', 'ford', 'mercedes_benz', 'seat', 'honda', 'fiat', 'mini', 'opel', 'smart', 'audi', 'alfa_romeo', 'subaru', 'mitsubishi', 'hyundai', 'volvo', 'lancia', 'porsche', 'citroen', 'toyota', 'kia', 'chevrolet', 'dacia', 'suzuki', 'daihatsu', 'chrysler', 'jaguar', 'rover', 'jeep', 'saab', 'daewoo', 'land_rover', 'trabant', 'lada'])

# %%
autos.brand.hist()
# Out:
# <AxesSubplot:>

# %%
import scipy.stats as sst

# %%
autos_price_powerPS = pd.DataFrame({'price' : autos['price'], 'powerPS' : autos['powerPS']})
autos_price_powerPS = autos_price_powerPS.dropna(how = 'any')
r, p = sst.pearsonr(autos_price_powerPS['price'], autos_price_powerPS['powerPS'])
print("p-value: " + str(p))
# Out:
# p-value: 0.011264291944669498

# %%
autos.size
# Out:
# 4957917

# %%
sns.distplot(autos['powerPS'], hist = False, kde = True)
# Out:
# C:\Users\Max\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='powerPS', ylabel='Density'>

# %%
sns.heatmap(autos[['price', 'powerPS']].corr('spearman'))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(autos[['price', 'powerPS']].corr('pearson'))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(autos.corr())
# Out:
# <AxesSubplot:>
