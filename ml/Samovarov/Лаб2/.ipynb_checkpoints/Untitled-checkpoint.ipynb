# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
happy_df = pd.read_csv('2017.csv',sep=',')
happy_df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 0       7.479556                  1.616463  1.533524
# 1       7.462272                  1.482383  1.551122
# 2       7.385970                  1.480633  1.610574
# 3       7.426227                  1.564980  1.516912
# 4       7.410458                  1.443572  1.540247
# ..           ...                       ...       ...
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 0                    0.796667  0.635423    0.362012
# 1                    0.792566  0.626007    0.355280
# 2                    0.833552  0.627163    0.475540
# 3                    0.858131  0.620071    0.290549
# 4                    0.809158  0.617951    0.245483
# ..                        ...       ...         ...
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# 152                  0.364509  0.390018    0.354256
# 153                  0.151611  0.059901    0.204435
# 154                  0.018773  0.270842    0.280876
#
#      Trust..Government.Corruption.  Dystopia.Residual
# 0                         0.315964           2.277027
# 1                         0.400770           2.313707
# 2                         0.153527           2.322715
# 3                         0.367007           2.276716
# 4                         0.382612           2.430182
# ..                             ...                ...
# 150                       0.455220           0.540061
# 151                       0.151347           1.061574
# 152                       0.066035           0.621130
# 153                       0.084148           1.683024
# 154                       0.056565           2.066005
#
# [155 rows x 12 columns]

# %%
#1. Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). 
plt.figure(figsize=(9, 9))

sb.heatmap(happy_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#2. Постройте график счастья по регионам, страны на графике должны представляться отдельными точками.
plt.figure(figsize=(22, 10));
plt.xticks(rotation = 90, fontsize = 8);
plt.yticks(np.arange(happy_df['Happiness.Score'].min(),happy_df['Happiness.Score'].max(),0.1));

plt.plot(happy_df['Country'], happy_df['Happiness.Score'], marker='o')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Python\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File D:\Python\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Python\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Happiness.Score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [172], in <cell line: 4>()
#       2 plt.figure(figsize=(22, 10));
#       3 plt.xticks(rotation = 90, fontsize = 8);
# ----> 4 plt.yticks(np.arange(happy_df['Happiness.Score'].min(),happy_df['Happiness.Score'].max(),0.1));
#       6 plt.plot(happy_df['Country'], happy_df['Happiness.Score'], marker='o')
#
# File D:\Python\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File D:\Python\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Happiness.Score'

# %%
#3. Оцените количество счастья по годам.
happy_df_15 = pd.read_csv('2015.csv',sep=',')
happy_df_16 = pd.read_csv('2016.csv',sep=',')
happy_df_17 = pd.read_csv('2017.csv',sep=',')

plt.subplot(2,2,1)
plt.tight_layout()
plt.title("2015")

plt.xticks(rotation = 90, fontsize = 8);
plt.grid();

plt.plot(happy_df_15['Country'].head(25), happy_df_15['Happiness Score'].head(25))

plt.subplot(2,2,2)
plt.tight_layout()
plt.title("2016")

plt.xticks(rotation = 90, fontsize = 8);
plt.grid();

plt.plot(happy_df_16['Country'].head(25), happy_df_16['Happiness Score'].head(25))

plt.subplot(2,2,3)
plt.tight_layout()
plt.title("2017")

plt.xticks(rotation = 90, fontsize = 8);
plt.grid();

plt.plot(happy_df_17['Country'].head(25), happy_df_17['Happiness.Score'].head(25))

# %%
#4. Определите наиболее сильно изменяющиеся параметры по разным странам в разные годы.
print("2015 year:")
std15 = happy_df_15.std(numeric_only=True)
print(std15)
print("\n")

print("2016 year:")
std16 = happy_df_16.std(numeric_only=True)
print(std16)
print("\n")

print("2017 year:")
std17 = happy_df_17.std(numeric_only=True)
print(std17)
print("\n")
# Out:
# 2015 year:
# Happiness Rank                   45.754363
# Happiness Score                   1.145010
# Standard Error                    0.017146
# Economy (GDP per Capita)          0.403121
# Family                            0.272369
# Health (Life Expectancy)          0.247078
# Freedom                           0.150693
# Trust (Government Corruption)     0.120034
# Generosity                        0.126685
# Dystopia Residual                 0.553550
# dtype: float64
#
#
# 2016 year:
# Happiness Rank                   45.466030
# Happiness Score                   1.141674
# Lower Confidence Interval         1.148043
# Upper Confidence Interval         1.136493
# Economy (GDP per Capita)          0.412595
# Family                            0.266706
# Health (Life Expectancy)          0.229349
# Freedom                           0.145507
# Trust (Government Corruption)     0.111038
# Generosity                        0.133756
# Dystopia Residual                 0.542220
# dtype: float64
#
#
# 2017 year:
# Happiness.Rank                   44.888751
# Happiness.Score                   1.131230
# Whisker.high                      1.118542
# Whisker.low                       1.145030
# Economy..GDP.per.Capita.          0.420793
# Family                            0.287263
# Health..Life.Expectancy.          0.237073
# Freedom                           0.149997
# Generosity                        0.134780
# Trust..Government.Corruption.     0.101661
# Dystopia.Residual                 0.500028
# dtype: float64

# %%
#5. Определите страны, появляющиеся и исчезающие в рейтинге стран.
sets15_16 = set(happy_df_15['Country'])
sets15_16.symmetric_difference_update(happy_df_16['Country'])

sets15_17 = set(happy_df_15['Country'])
sets15_17.symmetric_difference_update(happy_df_17['Country'])

sets15_16.union(sets15_17)
# Out:
# {'Belize',
#  'Central African Republic',
#  'Comoros',
#  'Djibouti',
#  'Hong Kong',
#  'Hong Kong S.A.R., China',
#  'Laos',
#  'Lesotho',
#  'Mozambique',
#  'Namibia',
#  'Oman',
#  'Puerto Rico',
#  'Somalia',
#  'Somaliland Region',
#  'Somaliland region',
#  'South Sudan',
#  'Suriname',
#  'Swaziland',
#  'Taiwan',
#  'Taiwan Province of China'}

# %%
#6. Удалите строки с пропущенными значениями. Выведите размер набора данных до и после удаления.
import random
pd.options.mode.chained_assignment = None
happy_df = pd.read_csv('2015.csv',sep=',')

print("Размер данных до удаления")
shapes = happy_df.shape
print("Количество строк: " + str(shapes[0]))

happy_df['Country'][np.random.choice(random.randint(10,157), random.randint(10,157))] = ''
happy_df.replace('', np.nan, inplace=True)
happy_df.dropna(inplace=True)

print("Размер данных после удаления")
shapes = happy_df.shape
print("Количество строк: " + str(shapes[0]))
# Out:
# Размер данных до удаления
# Количество строк: 158
# Размер данных после удаления
# Количество строк: 124

# %%
#7. Вычислите корреляцию Пирсона и Спирмена между признаками Trust.Government.Corruption и Family. Постройте гистограммы для указанных признаков. Оцените значение p-value.
from scipy import stats
print("Кореляция Спирмена:")
SpearmanCor = stats.spearmanr(happy_df_15['Trust (Government Corruption)'],happy_df_15['Family']) #happy_df_15[['Trust (Government Corruption)','Family']].corr(method='spearman') #corr(method='pearson')
print("Кореляция: " + str(SpearmanCor[0]) + " p-value: " + str(SpearmanCor[1]))

print("\n\n\n")

print("Кореляция Пирсона:")
PearsonCor = stats.pearsonr(happy_df_15['Trust (Government Corruption)'],happy_df_15['Family'])
print("Кореляция: " + str(PearsonCor[0]) + " p-value: " + str(PearsonCor[1]))

print("\n\n\n")

happy_df_15[['Trust (Government Corruption)','Family']].hist();
# Out:
# Кореляция Спирмена:
# Кореляция: 0.18459942329799503 p-value: 0.0202358284942051
#
#
#
#
# Кореляция Пирсона:
# Кореляция: 0.20560511187180402 p-value: 0.009551833256262039

# %%
#8 Признак являющийся суммой двух других признаков
happy_df_15['Res'] = happy_df_15['Economy (GDP per Capita)']+happy_df_15['Freedom']
happy_df_15
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual      Res
# 0       0.29678            2.51738  2.06208
# 1       0.43630            2.70201  1.93109
# 2       0.34139            2.49204  1.97486
# 3       0.34699            2.46531  2.12873
# 4       0.45811            2.45176  1.95926
# ..          ...                ...      ...
# 153     0.22628            0.67042  0.81409
# 154     0.18260            1.63328  0.77115
# 155     0.47179            0.32858  0.82004
# 156     0.19727            1.83302  0.13380
# 157     0.16681            1.56726  0.57321
#
# [158 rows x 13 columns]
